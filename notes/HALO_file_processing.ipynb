# %%
import numpy as np
import os
import re

class AmesTypeError(Exception):
    pass

class HeaderError(Exception):
    pass

class IncompleteRowError(Exception):
    pass

def is_number(s):
    try:
        float(s)
        return True
    except ValueError:
        return False

def parse_ames_1001_file(filename):
    try:      
        #open file and read contents
        f = open(filename, "r")
        lines = f.readlines()
        
        #check file type
        file_type = int(lines[0].split()[1])
        if file_type != 1001:
            raise AmesTypeError
            
        #get string array with variable labels
        num_header_lines = int(lines[0].split()[0])
        var_names = lines[num_header_lines - 1].split()
        
        #get file date
        infile_date = lines[6].split()[0:3]
        if len(infile_date[1]) == 1:
            infile_date[1] = '0' + infile_date[1]
        if len(infile_date[2]) == 1:
            infile_date[2] = '0' + infile_date[2]
            
        #get values for each data column which indicate an error has occured according to ames file format
        n_vars = int(lines[9]) + 1 #counting independent variable 
        first_scale_factor_line = lines[10].split()
        if len(first_scale_factor_line) != 1: #ames 'condensed' notation
            err_vals = np.array(lines[11].split()).astype(np.float)
        else:
            err_vals = np.array([float(lines[9 + n_vars + i]) for i in range(n_vars - 1)])   
            
        #make sure number of header lines indicated is correct
        if not is_number(lines[num_header_lines].split()[0]):
            raise HeaderError        

        #extract numerical data, removing empty lines (sometimes at the end of files)
        data = np.array([np.array(line.split()).astype(np.float) for line in lines[num_header_lines:-1] if line.split() != []])

        #check for rows with any column entries missing
        incomplete = False
        incomplete_rows = []
        for r, row in enumerate(data):
            if np.shape(row)[0] != n_vars:
                incomplete = True
                incomplete_rows.append((row[0], r + num_header_lines)) #records tuple of the form: (time var value, line number)
        if incomplete:
            raise IncompleteRowError

        return {'filename': filename, 'infile_date': infile_date,
                'var_names': var_names, 'err_vals': err_vals, 'data': data}
    
    except AmesTypeError:
        return {'filename': filename, 'error_type': 'ames', 'error_data': file_type}
        
    except HeaderError:
        return {'filename': filename, 'error_type': 'header', 
                'error_data': {'num_header_lines_reported': num_header_lines, 
                               'line_at_reported_start': lines[num_header_lines]}}
    
    except IncompleteRowError:
        return {'filename': filename, 'error_type': 'incomplete', 'error_data': incomplete_rows}
    
    except ValueError:
        #build data array manually, replacing any string-valued entries with the numerical code specified in header
        data = np.zeros([len(lines[num_header_lines:-1]), n_vars])
        for i, line in enumerate(lines[num_header_lines:-1]):
            row_str = line.split()
            for j, elt_str in enumerate(row_str):
                if is_number(elt_str):
                    elt = float(elt_str)
                else:
                    elt = err_vals[j]
                data[i,j] = elt
                
        #check for rows with any column entries missing
        incomplete = False
        incomplete_rows = []
        for r, row in enumerate(data):
            if np.shape(row)[0] != n_vars:
                incomplete = True
                incomplete_rows.append((row[0], r + num_header_lines)) #records tuple of the form: (time var value, line number)
        if incomplete:
            raise IncompleteRowError
                
        return {'filename': filename, 'infile_date': infile_date,
                'var_names': var_names, 'err_vals': err_vals, 'data': data}
    
    except:
        return{'filename': filename, 'error_type': 'unknown'}

# %%
all_good = []
ames_error = []
header_error = []
incomplete_error = []
other_error = []
wierd_ones = []

for filename in os.listdir('.'):
    if 'ames' in filename:
#     if filename[0] != '.' and ('ipynb' not in filename):
        print(filename) #for progress tracking
        file_data_dict = parse_ames_1001_file(filename)
        if 'error_type' in file_data_dict.keys():
            if file_data_dict['error_type'] == 'ames':
                ames_error.append(file_data_dict)
            elif file_data_dict['error_type'] == 'header':
                header_error.append(file_data_dict)
            elif file_data_dict['error_type'] == 'incomplete':
                incomplete_error.append(file_data_dict)
            elif file_data_dict['error_type'] == 'unknown':
                other_error.append(file_data_dict)
        else:
            all_good.append(file_data_dict)
# Out:
# HALO-DB_dataset1388_release1_adlr_20140901a_v02.ames
# HALO-DB_dataset1389_release1_adlr_20140902a_v02.ames
# HALO-DB_dataset1390_release1_adlr_20140906a_v02.ames
# HALO-DB_dataset1391_release1_adlr_20140909a_v02.ames
# HALO-DB_dataset1392_release1_adlr_20140911a_v02.ames
# HALO-DB_dataset1393_release2_adlr_20140916a_v03.ames
# HALO-DB_dataset1394_release2_adlr_20140918a_v03.ames
# HALO-DB_dataset1395_release1_adlr_20140919a_v02.ames
# HALO-DB_dataset1396_release1_adlr_20140921a.ames
# HALO-DB_dataset1397_release1_adlr_20140923a.ames
# HALO-DB_dataset1398_release1_adlr_20140925a.ames
# HALO-DB_dataset1436_release1_adlr_20140927a.ames
# HALO-DB_dataset1469_release1_sharc_20140906a.ames
# HALO-DB_dataset1470_release1_sharc_20140909a.ames
# HALO-DB_dataset1471_release1_sharc_20140911a.ames
# HALO-DB_dataset1472_release1_sharc_20140916a.ames
# HALO-DB_dataset1473_release1_sharc_20140918a.ames
# HALO-DB_dataset1474_release1_sharc_20140919a.ames
# HALO-DB_dataset1475_release1_sharc_20140921a.ames
# HALO-DB_dataset1476_release1_sharc_20140925a.ames
# HALO-DB_dataset1477_release1_sharc_20140927a.ames
# HALO-DB_dataset2814_release1_adlr_20140928a.ames
# HALO-DB_dataset2815_release1_adlr_20140930a.ames
# HALO-DB_dataset2816_release1_adlr_20141001a.ames
# HALO-DB_dataset2817_release1_adlr_20141003a_x.ames
# HALO-DB_dataset2818_release1_adlr_20141004a_x.ames
# HALO-DB_dataset2855_release1_sharc_20140928a.ames
# HALO-DB_dataset2856_release1_sharc_20140930a.ames
# HALO-DB_dataset2867_release1_sharc_20141004a.ames
# HALO-DB_dataset2868_release1_sharc_20141001a.ames
# HALO-DB_dataset2869_release1_sharc_20140901a.ames
# HALO-DB_dataset2870_release1_sharc_20140902a.ames
# HALO-DB_dataset2940_release1_sharc_20140912a.ames
# HALO-DB_dataset2941_release1_adlr_20140912a_v02.ames
# HALO-DB_dataset2942_release3_PIP_20140906a_V2.ames
# HALO-DB_dataset2943_release3_PIP_20140909a_V2.ames
# HALO-DB_dataset2944_release3_PIP_20140911a_V2.ames
# HALO-DB_dataset2945_release3_PIP_20140912a_V2.ames
# HALO-DB_dataset2946_release3_PIP_20140916a_V2.ames
# HALO-DB_dataset2947_release3_PIP_20140918a_V2.ames
# HALO-DB_dataset2948_release2_PIP_20140919a.ames
# HALO-DB_dataset2949_release2_PIP_20140921a.ames
# HALO-DB_dataset2950_release2_PIP_20140923a.ames
# HALO-DB_dataset2951_release2_PIP_20140925a.ames
# HALO-DB_dataset2952_release3_PIP_20140927a_V2.ames
# HALO-DB_dataset2953_release2_PIP_20140928a.ames
# HALO-DB_dataset2954_release2_PIP_20140930a.ames
# HALO-DB_dataset2955_release2_PIP_20141001a.ames
# HALO-DB_dataset2956_release3_CCP_CIPg_20140906a_V2.ames
# HALO-DB_dataset2957_release3_CCP_CIPg_20140909a_V2.ames
# HALO-DB_dataset2958_release3_CCP_CIPg_20140911a_V2.ames
# HALO-DB_dataset2959_release3_CCP_CIPg_20140912a_V2.ames
# HALO-DB_dataset2960_release3_CCP_CIPg_20140916a_V2.ames
# HALO-DB_dataset2961_release3_CCP_CIPg_20140918a_V2.ames
# HALO-DB_dataset2962_release3_CCP_CIPg_20140921a_V2.ames
# HALO-DB_dataset2963_release3_CCP_CIPg_20140927a_V2.ames
# HALO-DB_dataset2964_release3_CCP_CIPg_20140928a_V2.ames
# HALO-DB_dataset2965_release3_CCP_CIPg_20140930a_V2.ames
# HALO-DB_dataset2966_release3_CCP_CIPg_20141001a_V2.ames
# HALO-DB_dataset2968_release2_CCP_CDP_20140906a_V2.ames
# HALO-DB_dataset2969_release2_CCP_CDP_20140909a_V2.ames
# HALO-DB_dataset2970_release2_CCP_CDP_20140911a_V2.ames
# HALO-DB_dataset2971_release2_CCP_CDP_20140912a_V2.ames
# HALO-DB_dataset2972_release2_CCP_CDP_20140916a_V2.ames
# HALO-DB_dataset2973_release2_CCP_CDP_20140918a_V2.ames
# HALO-DB_dataset2974_release2_CCP_CDP_20140921a_V2.ames
# HALO-DB_dataset2975_release2_CCP_CDP_20140927a_V2.ames
# HALO-DB_dataset2976_release2_CCP_CDP_20140928a_V2.ames
# HALO-DB_dataset2977_release2_CCP_CDP_20140930a_V2.ames
# HALO-DB_dataset2978_release2_CCP_CDP_20141001a_V2.ames
# HALO-DB_dataset2995_release2_CCP_CDP_20140919a_V2.ames
# HALO-DB_dataset2996_release2_CCP_CIPg_20140919a_V2.ames
# HALO-DB_dataset3013_release5_CToFAMS_AC07_HASI_20140906.ames
# HALO-DB_dataset3014_release4_CToFAMS_AC08_HASI_20140909.ames
# HALO-DB_dataset3015_release4_CToFAMS_AC09_HASI_20140911.ames
# HALO-DB_dataset3019_release1_AC09_2014_09_11_CAS_V1.ames
# HALO-DB_dataset3020_release1_AC10_2014_09_12_CAS_V1.ames
# HALO-DB_dataset3021_release1_AC11_2014_09_16_CAS_V1.ames
# HALO-DB_dataset3022_release1_AC12_2014_09_18_CAS_V1.ames
# HALO-DB_dataset3023_release1_AC13_2014_09_19_CAS_V1.ames
# HALO-DB_dataset3024_release1_AC14_2014_09_21_CAS_V1.ames
# HALO-DB_dataset3025_release1_AC15_2014_09_23_CAS_V1.ames
# HALO-DB_dataset3026_release1_AC16_2014_09_25_CAS_V1.ames
# HALO-DB_dataset3027_release1_AC17_2014_09_27_CAS_V1.ames
# HALO-DB_dataset3029_release1_AC18_2014_09_28_CAS_V1.ames
# HALO-DB_dataset3030_release1_AC19_2014_09_30_CAS_V1.ames
# HALO-DB_dataset3031_release1_AC20_2014_10_01_CAS_V1.ames
# HALO-DB_dataset3032_release1_AC21_2014_10_03_CAS_V1.ames
# HALO-DB_dataset3033_release1_AC22_2014_10_04_CAS_V1.ames
# HALO-DB_dataset3047_release4_CToFAMS_AC11_HASI_20140916.ames
# HALO-DB_dataset3048_release4_CToFAMS_AC12_HASI_20140918.ames
# HALO-DB_dataset3049_release4_CToFAMS_AC13_HASI_20140919.ames
# HALO-DB_dataset3050_release4_CToFAMS_AC16_HASI_20140925.ames
# HALO-DB_dataset3051_release4_CToFAMS_AC17_HASI_20140927.ames
# HALO-DB_dataset3052_release4_CToFAMS_AC18_HASI_20140928.ames
# HALO-DB_dataset3053_release4_CToFAMS_AC19_HASI_20140930.ames
# HALO-DB_dataset3054_release4_CToFAMS_AC20_HASI_20141001.ames
# HALO-DB_dataset3055_release4_CToFAMS_AC15_HASI_20140923.ames
# HALO-DB_dataset3158_release2_ACRIDICON_AC05_FINCH_20140901_V1.ames
# HALO-DB_dataset3159_release1_ACRIDICON_AC08_FINCH_20140909_V1.ames
# HALO-DB_dataset3160_release1_ACRIDICON_AC10_FINCH_20140912_V1.ames
# HALO-DB_dataset3161_release1_ACRIDICON_AC11_FINCH_20140916_V1.ames
# HALO-DB_dataset3162_release1_ACRIDICON_AC13_FINCH_20140919_V1.ames
# HALO-DB_dataset3163_release1_ACRIDICON_AC14_FINCH_20140921_V1.ames
# HALO-DB_dataset3164_release1_ACRIDICON_AC18_FINCH_20140928_V1.ames
# HALO-DB_dataset3165_release1_ACRIDICON_AC19_FINCH_20140930_V1.ames
# HALO-DB_dataset3166_release1_ACRIDICON_AC20_FINCH_20141001_V1.ames
# HALO-DB_dataset3167_release5_acridicon2014_NIXECAPS_AC05_20140901_v6.ames
# HALO-DB_dataset3168_release5_acridicon2014_NIXECAPS_AC06_20140902_v6.ames
# HALO-DB_dataset3169_release5_acridicon2014_NIXECAPS_AC07_20140906_v6.ames
# HALO-DB_dataset3170_release6_acridicon2014_NIXECAPS_AC08_20140909_v6.ames
# HALO-DB_dataset3171_release5_acridicon2014_NIXECAPS_AC09_20140911_v6.ames
# HALO-DB_dataset3172_release5_acridicon2014_NIXECAPS_AC10_20140912_v6.ames
# HALO-DB_dataset3173_release5_acridicon2014_NIXECAPS_AC11_20140916_v6.ames
# HALO-DB_dataset3174_release5_acridicon2014_NIXECAPS_AC12_20140918_v6.ames
# HALO-DB_dataset3175_release5_acridicon2014_NIXECAPS_AC13_20140919_v6.ames
# HALO-DB_dataset3176_release5_acridicon2014_NIXECAPS_AC14_20140921_v6.ames
# HALO-DB_dataset3177_release5_acridicon2014_NIXECAPS_AC15_20140923_v6.ames
# HALO-DB_dataset3178_release5_acridicon2014_NIXECAPS_AC16_20140925_v6.ames
# HALO-DB_dataset3179_release5_acridicon2014_NIXECAPS_AC17_20140927_v6.ames
# HALO-DB_dataset3180_release5_acridicon2014_NIXECAPS_AC18_20140928_v6.ames
# HALO-DB_dataset3181_release5_acridicon2014_NIXECAPS_AC19_20140930_v6.ames
# HALO-DB_dataset3182_release5_acridicon2014_NIXECAPS_AC20_20141001_v6.ames
# HALO-DB_dataset3212_release1_AC05_AENEAS_2014_0901_NONOy_V1.ames
# HALO-DB_dataset3213_release1_AC06_AENEAS_2014_0902_NONOy_V1.ames
# HALO-DB_dataset3214_release1_AC07_AENEAS_2014_0906_NONOy_V1.ames
# HALO-DB_dataset3215_release1_AC12_AENEAS_2014_0918_NONOy_V1.ames
# HALO-DB_dataset3216_release1_AC13_AENEAS_2014_0919_NONOy_V1.ames
# HALO-DB_dataset3217_release1_AC14_AENEAS_2014_0921_NONOy_V1.ames
# HALO-DB_dataset3218_release1_AC15_AENEAS_2014_0923_NONOy_V1.ames
# HALO-DB_dataset3219_release2_AC16_AENEAS_2014_0925_NONOy_V2.ames
# HALO-DB_dataset3220_release1_AC17_AENEAS_2014_0927_NONOy_V1.ames
# HALO-DB_dataset3221_release1_AC18_AENEAS_2014_0928_NONOy_V1.ames
# HALO-DB_dataset3222_release1_AC19_AENEAS_2014_0930_NONOy_V1.ames
# HALO-DB_dataset3223_release1_AC20_AENEAS_2014_1001_NONOy_V1.ames
# HALO-DB_dataset3344_release4_UHSASA_AC05_20140901_R12.ames
# HALO-DB_dataset3345_release3_UHSASA_AC06_20140902_R12.ames
# HALO-DB_dataset3346_release3_UHSASA_AC07_20140906_R12.ames
# HALO-DB_dataset3347_release3_UHSASA_AC08_20140909_R12.ames
# HALO-DB_dataset3348_release3_UHSASA_AC09_20140911_R12.ames
# HALO-DB_dataset3349_release3_UHSASA_AC10_20140912_R12.ames
# HALO-DB_dataset3350_release3_UHSASA_AC11_20140916_R12.ames
# HALO-DB_dataset3351_release3_UHSASA_AC12_20140918_R12.ames
# HALO-DB_dataset3352_release3_UHSASA_AC13_20140919_R12.ames
# HALO-DB_dataset3353_release3_UHSASA_AC14_20140921_R12.ames
# HALO-DB_dataset3354_release3_UHSASA_AC15_20140923_R12.ames
# HALO-DB_dataset3355_release3_UHSASA_AC16_20140925_R12.ames
# HALO-DB_dataset3356_release3_UHSASA_AC18_20140928_R12.ames
# HALO-DB_dataset3357_release3_UHSASA_AC19_20140930_R12.ames
# HALO-DB_dataset3358_release3_UHSASA_AC20_20141001_R12.ames
# HALO-DB_dataset3359_release3_UHSASA_AC21_20141003_R12.ames
# HALO-DB_dataset3360_release3_UHSASA_AC22_20141004_R12.ames
# HALO-DB_dataset3361_release1_AC20_20141001_pcasp.ames
# HALO-DB_dataset3362_release1_AC08_20140909_pcasp.ames
# HALO-DB_dataset3363_release1_AC18_20140928_pcasp.ames
# HALO-DB_dataset3364_release1_AC17_20140927_pcasp.ames
# HALO-DB_dataset3365_release1_AC16_20140925_pcasp.ames
# HALO-DB_dataset3366_release1_AC15_20140923_pcasp.ames
# HALO-DB_dataset3367_release1_AC13_20140919_pcasp.ames
# HALO-DB_dataset3368_release1_AC12_20140918_pcasp.ames
# HALO-DB_dataset3369_release1_AC11_20140916_pcasp.ames
# HALO-DB_dataset3370_release1_AC19_20140930_pcasp.ames
# HALO-DB_dataset3387_release1_AC8_miniDOAS_140909_dSCDs_v1.ames
# HALO-DB_dataset3388_release1_AC9_miniDOAS_140911_dSCDs_v1.ames
# HALO-DB_dataset3390_release1_AC10_miniDOAS_140912_dSCDs_v1.ames
# HALO-DB_dataset3391_release1_AC11_miniDOAS_140916_dSCDs_v1.ames
# HALO-DB_dataset3392_release1_AC12_miniDOAS_140918_dSCDs_v1.ames
# HALO-DB_dataset3393_release1_AC13_miniDOAS_140919_dSCDs_v1.ames
# HALO-DB_dataset3394_release5_AC16_2014_09_25_AMETYST_CPC1TD_V4.ames
# HALO-DB_dataset3395_release5_AC17_2014_09_27_AMETYST_CPC1TD_V4.ames
# HALO-DB_dataset3396_release5_AC18_2014_09_28_AMETYST_CPC1TD_V4.ames
# HALO-DB_dataset3397_release5_AC19_2014_09_30_AMETYST_CPC1TD_V4.ames
# HALO-DB_dataset3398_release5_AC20_2014_10_01_AMETYST_CPC1TD_V4.ames
# HALO-DB_dataset3411_release1_AC09_20140911_pcasp.ames
# HALO-DB_dataset3412_release1_AC09_20140911_pcasp.ames
# HALO-DB_dataset3413_release1_AC10_20140912_pcasp.ames
# HALO-DB_dataset3420_release2_ACRIDICON_AC05_SID3_SD.ames
# HALO-DB_dataset3421_release2_ACRIDICON_AC06_SID3_SD.ames
# HALO-DB_dataset3423_release2_ACRIDICON_AC07b_SID3_SD.ames
# HALO-DB_dataset3425_release1_ACRIDICON_AC08_SID3_SD.ames
# HALO-DB_dataset3426_release1_ACRIDICON_AC09_SID3_SD.ames
# HALO-DB_dataset3427_release1_ACRIDICON_AC10_SID3_SD.ames
# HALO-DB_dataset3428_release3_phipshalo_pbp_C1_140923a.ames
# HALO-DB_dataset3429_release1_phipshalo_pbp_C2_140923a.ames
# HALO-DB_dataset3430_release1_phipshalo_pbp_C1_140925a.ames
# HALO-DB_dataset3431_release1_phipshalo_pbp_C2_140925a.ames
# HALO-DB_dataset3432_release1_phipshalo_pbp_C1_141001a.ames
# HALO-DB_dataset3433_release1_phipshalo_pbp_C2_141001a.ames
# HALO-DB_dataset3435_release1_phipshalo_pbp_C1_140919a.ames
# HALO-DB_dataset3436_release1_phipshalo_pbp_C2_140919a.ames
# HALO-DB_dataset3437_release1_AC05_2014_09_01_AMTEX_CO_V1.ames
# HALO-DB_dataset3438_release1_AC06_2014_09_02_AMTEX_CO_V1.ames
# HALO-DB_dataset3439_release1_AC07_2014_09_06_AMTEX_CO_V1.ames
# HALO-DB_dataset3440_release1_AC11_2014_09_16_AMTEX_CO_V1.ames
# HALO-DB_dataset3441_release1_AC12_2014_09_18_AMTEX_CO_V1.ames
# HALO-DB_dataset3442_release1_AC13_2014_09_19_AMTEX_CO_V1.ames
# HALO-DB_dataset3443_release1_AC14_2014_09_21_AMTEX_CO_V1.ames
# HALO-DB_dataset3444_release1_AC15_2014_09_23_AMTEX_CO_V1.ames
# HALO-DB_dataset3445_release1_AC16_2014_09_25_AMTEX_CO_V1.ames
# HALO-DB_dataset3446_release1_AC17_2014_09_27_AMTEX_CO_V1.ames
# HALO-DB_dataset3447_release1_AC18_2014_09_28_AMTEX_CO_V1.ames
# HALO-DB_dataset3448_release1_AC19_2014_09_30_AMTEX_CO_V1.ames
# HALO-DB_dataset3449_release2_AC20_2014_10_01_AMTEX_CO_V1.ames
# HALO-DB_dataset3450_release1_AC21_2014_10_03_AMTEX_CO_V1.ames
# HALO-DB_dataset3451_release1_AC22_2014_10_04_AMTEX_CO_V1.ames
# HALO-DB_dataset3452_release1_AC05_2014_09_01_Ozone_V1.ames
# HALO-DB_dataset3453_release1_AC06_2014_09_02_Ozone_V1.ames
# HALO-DB_dataset3454_release1_AC07_2014_09_06_Ozone_V1.ames
# HALO-DB_dataset3455_release1_AC08_2014_09_09_Ozone_V1.ames
# HALO-DB_dataset3456_release1_AC09_2014_09_11_Ozone_V1.ames
# HALO-DB_dataset3457_release1_AC10_2014_09_12_Ozone_V1.ames
# HALO-DB_dataset3458_release1_AC11_2014_09_16_Ozone_V1.ames
# HALO-DB_dataset3459_release1_AC12_2014_09_18_Ozone_V1.ames
# HALO-DB_dataset3460_release1_AC13_2014_09_19_Ozone_V1.ames
# HALO-DB_dataset3461_release1_AC14_2014_09_21_Ozone_V1.ames
# HALO-DB_dataset3462_release1_AC15_2014_09_23_Ozone_V1.ames
# HALO-DB_dataset3463_release1_AC16_2014_09_25_Ozone_V1.ames
# HALO-DB_dataset3464_release1_AC17_2014_09_27_Ozone_V1.ames
# HALO-DB_dataset3465_release1_AC18_2014_09_28_Ozone_V1.ames
# HALO-DB_dataset3466_release1_AC19_2014_09_30_Ozone_V1.ames
# HALO-DB_dataset3468_release1_AC20_2014_10_01_Ozone_V1.ames
# HALO-DB_dataset3469_release1_AC21_2014_10_03_Ozone_V1.ames
# HALO-DB_dataset3470_release1_AC22_2014_10_04_Ozone_V1.ames
# HALO-DB_dataset3471_release1_ACRIDICON_AC11_SID3_SD.ames
# HALO-DB_dataset3472_release1_ACRIDICON_AC12_SID3_SD.ames
# HALO-DB_dataset3503_release2_ACRIDICON_HAI14_closedpath_gasphase_SW03_20140901.ames
# HALO-DB_dataset3504_release2_ACRIDICON_HAI14_closedpath_gasphase_SW03_20140902.ames
# HALO-DB_dataset3505_release2_ACRIDICON_HAI14_closedpath_gasphase_SW03_20140906.ames
# HALO-DB_dataset3506_release2_ACRIDICON_HAI14_closedpath_gasphase_SW03_20140909.ames
# HALO-DB_dataset3507_release2_ACRIDICON_HAI14_closedpath_gasphase_SW03_20140911.ames
# HALO-DB_dataset3508_release2_ACRIDICON_HAI14_closedpath_gasphase_SW03_20140912.ames
# HALO-DB_dataset3509_release2_ACRIDICON_HAI14_closedpath_gasphase_SW03_20140916.ames
# HALO-DB_dataset3510_release2_ACRIDICON_HAI14_closedpath_gasphase_SW03_20140918.ames
# HALO-DB_dataset3511_release2_ACRIDICON_HAI14_closedpath_gasphase_SW03_20140919.ames
# HALO-DB_dataset3512_release2_ACRIDICON_HAI14_closedpath_gasphase_SW03_20140923.ames
# HALO-DB_dataset3513_release2_ACRIDICON_HAI14_closedpath_gasphase_SW03_20140925.ames
# HALO-DB_dataset3514_release2_ACRIDICON_HAI14_closedpath_gasphase_SW03_20140927.ames
# HALO-DB_dataset3515_release2_ACRIDICON_HAI14_closedpath_gasphase_SW03_20140928.ames
# HALO-DB_dataset3516_release2_ACRIDICON_HAI14_closedpath_gasphase_SW03_20140930.ames
# HALO-DB_dataset3517_release2_ACRIDICON_HAI14_closedpath_gasphase_SW03_20141001.ames
# HALO-DB_dataset3518_release2_ACRIDICON_HAI14_closedpath_gasphase_SW03_20141003.ames
# HALO-DB_dataset3519_release2_ACRIDICON_HAI14_closedpath_gasphase_SW03_20141004.ames
# HALO-DB_dataset3520_release1_ACRIDICON_HAI14_closedpath_gasphase_SW03_20140921.ames
# HALO-DB_dataset3536_release1_phipshalo_pbp_C1_140918a.ames
# HALO-DB_dataset3537_release1_phipshalo_pbp_C2_140918a.ames
# HALO-DB_dataset3538_release1_ACRIDICONCHUVA_AC07_CVI_20140906_V1.ames
# HALO-DB_dataset3539_release1_ACRIDICONCHUVA_AC08_CVI_20140909_V1.ames
# HALO-DB_dataset3540_release1_ACRIDICONCHUVA_AC09_CVI_20140911_V1.ames
# HALO-DB_dataset3541_release1_ACRIDICONCHUVA_AC10_CVI_20140912_V1.ames
# HALO-DB_dataset3542_release1_ACRIDICONCHUVA_AC11_CVI_20140916_V1.ames
# HALO-DB_dataset3543_release1_ACRIDICONCHUVA_AC12_CVI_20140918_V1.ames
# HALO-DB_dataset3544_release1_ACRIDICONCHUVA_AC13_CVI_20140919_V1.ames
# HALO-DB_dataset3545_release1_ACRIDICONCHUVA_AC14_CVI_20140921_V1.ames
# HALO-DB_dataset3546_release1_ACRIDICONCHUVA_AC15_CVI_20140923_V1.ames
# HALO-DB_dataset3547_release1_ACRIDICONCHUVA_AC16_CVI_20140925_V1.ames
# HALO-DB_dataset3548_release1_ACRIDICONCHUVA_AC17_CVI_20140927_V1.ames
# HALO-DB_dataset3549_release1_ACRIDICONCHUVA_AC18_CVI_20140928_V1.ames
# HALO-DB_dataset3550_release1_ACRIDICONCHUVA_AC19_CVI_20140930_V1.ames
# HALO-DB_dataset3551_release1_ACRIDICONCHUVA_AC20_CVI_20141001_V1.ames
# HALO-DB_dataset3582_release1_phipshalo_pbp_C1_140928a.ames
# HALO-DB_dataset3583_release1_phipshalo_pbp_C2_140928a.ames
# HALO-DB_dataset3584_release1_phipshalo_pbp_C1_140921a.ames
# HALO-DB_dataset3585_release1_phipshalo_pbp_C2_140921a.ames
# HALO-DB_dataset3586_release1_phipshalo_pbp_C1_140916a.ames
# HALO-DB_dataset3587_release1_phipshalo_pbp_C2_140916a.ames
# HALO-DB_dataset3619_release3_CAS_DPOL_AC09__11_09_2014_ACRIDICON_v3.ames
# HALO-DB_dataset3620_release3_CAS_DPOL_AC10__12_09_2014_ACRIDICON_v3.ames
# HALO-DB_dataset3621_release3_CAS_DPOL_AC11__16_09_2014_ACRIDICON_v3.ames
# HALO-DB_dataset3622_release3_CAS_DPOL_AC12__18_09_2014_ACRIDICON_v3.ames
# HALO-DB_dataset3623_release3_CAS_DPOL_AC13__19_09_2014_ACRIDICON_v3.ames
# HALO-DB_dataset3624_release3_CAS_DPOL_AC14__21_09_2014_ACRIDICON_v3.ames
# HALO-DB_dataset3625_release3_CAS_DPOL_AC15__23_09_2014_ACRIDICON_v3.ames
# HALO-DB_dataset3626_release4_CAS_DPOL_AC16__25_09_2014_ACRIDICON_v3.ames
# HALO-DB_dataset3627_release3_CAS_DPOL_AC17__27_09_2014_ACRIDICON_v3.ames
# HALO-DB_dataset3628_release3_CAS_DPOL_AC18__28_09_2014_ACRIDICON_v3.ames
# HALO-DB_dataset3629_release3_CAS_DPOL_AC19__30_09_2014_ACRIDICON_v3.ames
# HALO-DB_dataset3630_release3_CAS_DPOL_AC20__01_10_2014_ACRIDICON_v3.ames
# HALO-DB_dataset3631_release3_CAS_DPOL_AC21__03_10_2014_ACRIDICON_v3.ames
# HALO-DB_dataset3632_release3_CAS_DPOL_AC22__04_10_2014_ACRIDICON_v3.ames
# HALO-DB_dataset3697_release1_ACRIDICONCHUVA_SMART_AC05_20140901a.ames
# HALO-DB_dataset3698_release1_ACRIDICONCHUVA_SMART_20140902a.ames
# HALO-DB_dataset3699_release1_ACRIDICONCHUVA_SMART_20140906a.ames
# HALO-DB_dataset3700_release1_ACRIDICONCHUVA_SMART_20140909a.ames
# HALO-DB_dataset3701_release1_ACRIDICONCHUVA_SMART_20140912a.ames
# HALO-DB_dataset3702_release1_ACRIDICONCHUVA_SMART_20140916a.ames
# HALO-DB_dataset3703_release1_ACRIDICONCHUVA_SMART_20140918a.ames
# HALO-DB_dataset3704_release1_ACRIDICONCHUVA_SMART_20140919a.ames
# HALO-DB_dataset3705_release1_ACRIDICONCHUVA_SMART_20140921a.ames
# HALO-DB_dataset3706_release1_ACRIDICONCHUVA_SMART_20140923a.ames
# HALO-DB_dataset3707_release1_ACRIDICONCHUVA_SMART_20140925a.ames
# HALO-DB_dataset3708_release1_ACRIDICONCHUVA_SMART_20140927a.ames
# HALO-DB_dataset3709_release1_ACRIDICONCHUVA_SMART_20140928a.ames
# HALO-DB_dataset3710_release1_ACRIDICONCHUVA_SMART_20140930a.ames
# HALO-DB_dataset3711_release1_ACRIDICONCHUVA_SMART_20141001a.ames
# HALO-DB_dataset3798_release1_140930_phipshalo_pbp_C1.ames
# HALO-DB_dataset3799_release1_140930_phipshalo_pbp_C2.ames
# HALO-DB_dataset3813_release4_AC07_2014_09_06_AMETYST_CPC0_CPC3_V4.ames
# HALO-DB_dataset3814_release4_AC08_2014_09_09_AMETYST_CPC0_CPC3_V4.ames
# HALO-DB_dataset3815_release4_AC09_2014_09_11_AMETYST_CPC0_CPC3_V4.ames
# HALO-DB_dataset3816_release4_AC10_2014_09_12_AMETYST_CPC0_CPC3_V4.ames
# HALO-DB_dataset3817_release5_AC11_2014_09_16_AMETYST_CPC0_CPC3_V4.ames
# HALO-DB_dataset3818_release4_AC12_2014_09_18_AMETYST_CPC0_CPC3_V4.ames
# HALO-DB_dataset3819_release5_AC13_2014_09_19_AMETYST_CPC0_CPC3_V4.ames
# HALO-DB_dataset3820_release4_AC14_2014_09_21_AMETYST_CPC0_CPC3_V4.ames
# HALO-DB_dataset3822_release4_AC15_2014_09_23_AMETYST_CPC0_CPC3_V4.ames
# HALO-DB_dataset3823_release4_AC16_2014_09_25_AMETYST_CPC0_CPC3_V4.ames
# HALO-DB_dataset3824_release4_AC17_2014_09_27_AMETYST_CPC0_CPC3_V4.ames
# HALO-DB_dataset3825_release4_AC18_2014_09_28_AMETYST_CPC0_CPC3_V4.ames
# HALO-DB_dataset3826_release4_AC19_2014_09_30_AMETYST_CPC0_CPC3_V4.ames
# HALO-DB_dataset3827_release4_AC20_2014_10_01_AMETYST_CPC0_CPC3_V4.ames
# HALO-DB_dataset3913_release1_Hotwire_AC07__06_09_2014_ACRIDICON.ames
# HALO-DB_dataset3914_release1_CAS_DPOL_AC09__11_09_2014_ACRIDICON.ames
# HALO-DB_dataset3915_release1_Hotwire_AC10__12_09_2014_ACRIDICON.ames
# HALO-DB_dataset3916_release1_Hotwire_AC11__16_09_2014_ACRIDICON.ames
# HALO-DB_dataset3917_release1_CAS_DPOL_AC12__18_09_2014_ACRIDICON.ames
# HALO-DB_dataset3918_release1_Hotwire_AC13__19_09_2014_ACRIDICON.ames
# HALO-DB_dataset3919_release1_Hotwire_AC14__21_09_2014_ACRIDICON.ames
# HALO-DB_dataset3920_release1_Hotwire_AC15__23_09_2014_ACRIDICON.ames
# HALO-DB_dataset3921_release1_Hotwire_AC16__25_09_2014_ACRIDICON.ames
# HALO-DB_dataset3922_release1_Hotwire_AC17__27_09_2014_ACRIDICON.ames
# HALO-DB_dataset3923_release1_Hotwire_AC18__28_09_2014_ACRIDICON.ames
# HALO-DB_dataset3924_release1_Hotwire_AC19__30_09_2014_ACRIDICON.ames
# HALO-DB_dataset3925_release1_Hotwire_AC20__01_10_2014_ACRIDICON.ames
# HALO-DB_dataset3926_release1_Hotwire_AC21__03_10_2014_ACRIDICON.ames
# HALO-DB_dataset3927_release1_Hotwire_AC22__04_10_2014_ACRIDICON.ames
# HALO-DB_dataset3928_release2_CAS_DPOL_AC08__09_09_2014_ACRIDICON_v3.ames
# HALO-DB_dataset3929_release3_CAS_DPOL_AC07__06_09_2014_ACRIDICON_v3.ames
# HALO-DB_dataset4732_release1_NIXECAPS_cloudflag_AC05_2014_09_01.ames
# HALO-DB_dataset4733_release1_NIXECAPS_cloudflag_AC06_2014_09_02.ames
# HALO-DB_dataset4734_release1_NIXECAPS_cloudflag_AC07_2014_09_06.ames
# HALO-DB_dataset4735_release1_NIXECAPS_cloudflag_AC09_2014_09_11.ames
# HALO-DB_dataset4736_release1_NIXECAPS_cloudflag_AC08_2014_09_09.ames
# HALO-DB_dataset4737_release1_NIXECAPS_cloudflag_AC10_2014_09_12.ames
# HALO-DB_dataset4738_release1_NIXECAPS_cloudflag_AC11_2014_09_16.ames
# HALO-DB_dataset4739_release1_NIXECAPS_cloudflag_AC12_2014_09_18.ames
# HALO-DB_dataset4740_release1_NIXECAPS_cloudflag_AC12_2014_09_18.ames
# HALO-DB_dataset4741_release1_NIXECAPS_cloudflag_AC13_2014_09_19.ames
# HALO-DB_dataset4742_release1_NIXECAPS_cloudflag_AC14_2014_09_21.ames
# HALO-DB_dataset4743_release1_NIXECAPS_cloudflag_AC15_2014_09_23.ames
# HALO-DB_dataset4744_release1_NIXECAPS_cloudflag_AC16_2014_09_25.ames
# HALO-DB_dataset4745_release1_NIXECAPS_cloudflag_AC17_2014_09_27.ames
# HALO-DB_dataset4746_release1_NIXECAPS_cloudflag_AC18_2014_09_28.ames
# HALO-DB_dataset4747_release1_NIXECAPS_cloudflag_AC19_2014_09_30.ames
# HALO-DB_dataset4748_release1_NIXECAPS_cloudflag_AC20_2014_10_01.ames
# HALO-DB_dataset4793_release1_AC11_AENEAS_2014_0916_NONOy_V2.ames
# HALO-DB_dataset4924_release4_CToFAMS_CVI_AC07_20140906.ames
# HALO-DB_dataset4925_release3_CToFAMS_CVI_AC08_20140909.ames
# HALO-DB_dataset4926_release2_CToFAMS_CVI_AC09_20140911.ames
# HALO-DB_dataset4927_release2_CToFAMS_CVI_AC11_20140916.ames
# HALO-DB_dataset4928_release2_CToFAMS_CVI_AC12_20140918.ames
# HALO-DB_dataset4929_release2_CToFAMS_CVI_AC13_20140919.ames
# HALO-DB_dataset4930_release2_CToFAMS_CVI_AC14_20140921.ames
# HALO-DB_dataset4931_release2_CToFAMS_CVI_AC15_20140923.ames
# HALO-DB_dataset4932_release2_CToFAMS_CVI_AC16_20140925.ames
# HALO-DB_dataset4933_release2_CToFAMS_CVI_AC18_20140928.ames
# HALO-DB_dataset4934_release2_CToFAMS_CVI_AC19_20140930.ames
# HALO-DB_dataset4935_release2_CToFAMS_CVI_AC20_20141001.ames
# HALO-DB_dataset4936_release2_CToFAMS_CVI_AC17_20140927.ames
# HALO-DB_dataset4995_release3_CToFAMS_AC14_HASI_20140921.ames
# HALO-DB_dataset5398_release1_CCNC_HASI_AC07_140906a.ames
# HALO-DB_dataset5399_release1_CCNC_HASI_AC08_140909a.ames
# HALO-DB_dataset5400_release1_CCNC_HASI_AC09_140911a.ames
# HALO-DB_dataset5401_release1_CCNC_HASI_AC11_140916a.ames
# HALO-DB_dataset5402_release1_CCNC_HASI_AC12_140918a.ames
# HALO-DB_dataset5403_release1_CCNC_HASI_AC13_140919a.ames
# HALO-DB_dataset5404_release1_CCNC_HASI_AC14_140921a.ames
# HALO-DB_dataset5405_release1_CCNC_HASI_AC15_140923a.ames
# HALO-DB_dataset5406_release1_CCNC_HASI_AC16_140925a.ames
# HALO-DB_dataset5407_release1_CCNC_HASI_AC17_140927a.ames
# HALO-DB_dataset5408_release1_CCNC_HASI_AC18_140928a.ames
# HALO-DB_dataset5409_release1_CCNC_HASI_AC19_140930a.ames
# HALO-DB_dataset5410_release1_CCNC_HASI_AC20_141001a.ames
# HALO-DB_dataset5411_release1_CCNC_HASI_AC10_140912a.ames
# HALO-DB_dataset5818_release2_UHSASA_AC17_20140927_R12.ames
# HALO-DB_dataset6396_release1_CToFAMS_CVI_AC10_20140912.ames

# %%
# FIRST RUN #

print(len(all_good), ' files processed with no error.')
print()
print(len(ames_error), ' files not in ames 1001-type format:')
for thing in ames_error:
    print(thing['filename'])
print()    
print(len(header_error), ' files with header error:')
for thing in header_error:
    print(thing['filename'])
print()    
print(len(incomplete_error), ' files with incomplete data rows:')
for thing in incomplete_error:
    print(thing['filename'])
print()
print(len(other_error), ' files with unknown error:')
for thing in other_error:
    print(thing['filename'])
# Out:
# 321  files processed with no error.
#
# 18  files not in ames 1001-type format:
# HALO-DB_dataset3649_release1_LPDMFLEXPARTAC5.ames
# HALO-DB_dataset3650_release1_LPDMFLEXPARTAC6.ames
# HALO-DB_dataset3651_release1_LPDMFLEXPARTAC7.ames
# HALO-DB_dataset3652_release1_LPDMFLEXPARTAC8.ames
# HALO-DB_dataset3653_release1_LPDMFLEXPARTAC9.ames
# HALO-DB_dataset3654_release1_LPDMFLEXPARTAC10.ames
# HALO-DB_dataset3655_release1_LPDMFLEXPARTAC11.ames
# HALO-DB_dataset3656_release1_LPDMFLEXPARTAC12.ames
# HALO-DB_dataset3657_release1_LPDMFLEXPARTAC13.ames
# HALO-DB_dataset3658_release1_LPDMFLEXPARTAC14.ames
# HALO-DB_dataset3659_release1_LPDMFLEXPARTAC15.ames
# HALO-DB_dataset3661_release1_LPDMFLEXPARTAC16.ames
# HALO-DB_dataset3662_release1_LPDMFLEXPARTAC17.ames
# HALO-DB_dataset3663_release1_LPDMFLEXPARTAC18.ames
# HALO-DB_dataset3664_release1_LPDMFLEXPARTAC19.ames
# HALO-DB_dataset3665_release1_LPDMFLEXPARTAC20.ames
# HALO-DB_dataset3666_release1_LPDMFLEXPARTAC21.ames
# HALO-DB_dataset3667_release1_LPDMFLEXPARTAC22.ames
#
# 37  files with header error:
# HALO-DB_dataset3158_release2_ACRIDICON_AC05_FINCH_20140901_V1.ames
# HALO-DB_dataset3159_release1_ACRIDICON_AC08_FINCH_20140909_V1.ames
# HALO-DB_dataset3160_release1_ACRIDICON_AC10_FINCH_20140912_V1.ames
# HALO-DB_dataset3162_release1_ACRIDICON_AC13_FINCH_20140919_V1.ames
# HALO-DB_dataset3163_release1_ACRIDICON_AC14_FINCH_20140921_V1.ames
# HALO-DB_dataset3164_release1_ACRIDICON_AC18_FINCH_20140928_V1.ames
# HALO-DB_dataset3165_release1_ACRIDICON_AC19_FINCH_20140930_V1.ames
# HALO-DB_dataset3166_release1_ACRIDICON_AC20_FINCH_20141001_V1.ames
# HALO-DB_dataset3421_release2_ACRIDICON_AC06_SID3_SD.ames
# HALO-DB_dataset3913_release1_Hotwire_AC07__06_09_2014_ACRIDICON.ames
# HALO-DB_dataset3914_release1_CAS_DPOL_AC09__11_09_2014_ACRIDICON.ames
# HALO-DB_dataset3915_release1_Hotwire_AC10__12_09_2014_ACRIDICON.ames
# HALO-DB_dataset3916_release1_Hotwire_AC11__16_09_2014_ACRIDICON.ames
# HALO-DB_dataset3918_release1_Hotwire_AC13__19_09_2014_ACRIDICON.ames
# HALO-DB_dataset3919_release1_Hotwire_AC14__21_09_2014_ACRIDICON.ames
# HALO-DB_dataset3920_release1_Hotwire_AC15__23_09_2014_ACRIDICON.ames
# HALO-DB_dataset3921_release1_Hotwire_AC16__25_09_2014_ACRIDICON.ames
# HALO-DB_dataset3922_release1_Hotwire_AC17__27_09_2014_ACRIDICON.ames
# HALO-DB_dataset3923_release1_Hotwire_AC18__28_09_2014_ACRIDICON.ames
# HALO-DB_dataset3924_release1_Hotwire_AC19__30_09_2014_ACRIDICON.ames
# HALO-DB_dataset3925_release1_Hotwire_AC20__01_10_2014_ACRIDICON.ames
# HALO-DB_dataset3926_release1_Hotwire_AC21__03_10_2014_ACRIDICON.ames
# HALO-DB_dataset3927_release1_Hotwire_AC22__04_10_2014_ACRIDICON.ames
# HALO-DB_dataset5398_release1_CCNC_HASI_AC07_140906a.ames
# HALO-DB_dataset5399_release1_CCNC_HASI_AC08_140909a.ames
# HALO-DB_dataset5400_release1_CCNC_HASI_AC09_140911a.ames
# HALO-DB_dataset5401_release1_CCNC_HASI_AC11_140916a.ames
# HALO-DB_dataset5402_release1_CCNC_HASI_AC12_140918a.ames
# HALO-DB_dataset5403_release1_CCNC_HASI_AC13_140919a.ames
# HALO-DB_dataset5404_release1_CCNC_HASI_AC14_140921a.ames
# HALO-DB_dataset5405_release1_CCNC_HASI_AC15_140923a.ames
# HALO-DB_dataset5406_release1_CCNC_HASI_AC16_140925a.ames
# HALO-DB_dataset5407_release1_CCNC_HASI_AC17_140927a.ames
# HALO-DB_dataset5408_release1_CCNC_HASI_AC18_140928a.ames
# HALO-DB_dataset5409_release1_CCNC_HASI_AC19_140930a.ames
# HALO-DB_dataset5410_release1_CCNC_HASI_AC20_141001a.ames
# HALO-DB_dataset5411_release1_CCNC_HASI_AC10_140912a.ames
#
# 16  files with incomplete data rows:
# HALO-DB_dataset3019_release1_AC09_2014_09_11_CAS_V1.ames
# HALO-DB_dataset3020_release1_AC10_2014_09_12_CAS_V1.ames
# HALO-DB_dataset3021_release1_AC11_2014_09_16_CAS_V1.ames
# HALO-DB_dataset3022_release1_AC12_2014_09_18_CAS_V1.ames
# HALO-DB_dataset3023_release1_AC13_2014_09_19_CAS_V1.ames
# HALO-DB_dataset3024_release1_AC14_2014_09_21_CAS_V1.ames
# HALO-DB_dataset3025_release1_AC15_2014_09_23_CAS_V1.ames
# HALO-DB_dataset3026_release1_AC16_2014_09_25_CAS_V1.ames
# HALO-DB_dataset3027_release1_AC17_2014_09_27_CAS_V1.ames
# HALO-DB_dataset3029_release1_AC18_2014_09_28_CAS_V1.ames
# HALO-DB_dataset3030_release1_AC19_2014_09_30_CAS_V1.ames
# HALO-DB_dataset3031_release1_AC20_2014_10_01_CAS_V1.ames
# HALO-DB_dataset3032_release1_AC21_2014_10_03_CAS_V1.ames
# HALO-DB_dataset3033_release1_AC22_2014_10_04_CAS_V1.ames
# HALO-DB_dataset3052_release4_CToFAMS_AC18_HASI_20140928.ames
# HALO-DB_dataset3917_release1_CAS_DPOL_AC12__18_09_2014_ACRIDICON.ames
#
# 1  files with unknown error:
# HALO-DB_dataset3016_release3_CToFAMS_AC10_HASI_20140912.ames

# %%
# NOTES

# In addition to edits to headers, the following in-file dates were corrected:
# dataset 2946: corrected to 09/16
# dataset 3025: corrected to 09/23
# dataset 3468: corrected to 10/01
# dataset 3651: corrected to 09/06

# dataset 3016: data are missing

# datasets 3019-3033: actually have too many columns...

# dataset 3052: timestamp missing line 342; I interpolated to 60740

# dataset 3917: appears to be missing a column

# dataset 3929: second two copies of data were deleted

# %%
# SECOND RUN #

print(len(all_good), ' files processed with no error.')
print()
print(len(ames_error), ' files not in ames 1001-type format:')
for thing in ames_error:
    print(thing['filename'])
print()    
print(len(header_error), ' files with header error:')
for thing in header_error:
    print(thing['filename'])
print()    
print(len(incomplete_error), ' files with incomplete data rows:')
for thing in incomplete_error:
    print(thing['filename'])
print()
print(len(other_error), ' files with unknown error:')
for thing in other_error:
    print(thing['filename'])
# Out:
# 351  files processed with no error.
#
# 18  files not in ames 1001-type format:
# HALO-DB_dataset3649_release1_LPDMFLEXPARTAC5.ames
# HALO-DB_dataset3650_release1_LPDMFLEXPARTAC6.ames
# HALO-DB_dataset3651_release1_LPDMFLEXPARTAC7.ames
# HALO-DB_dataset3652_release1_LPDMFLEXPARTAC8.ames
# HALO-DB_dataset3653_release1_LPDMFLEXPARTAC9.ames
# HALO-DB_dataset3654_release1_LPDMFLEXPARTAC10.ames
# HALO-DB_dataset3655_release1_LPDMFLEXPARTAC11.ames
# HALO-DB_dataset3656_release1_LPDMFLEXPARTAC12.ames
# HALO-DB_dataset3657_release1_LPDMFLEXPARTAC13.ames
# HALO-DB_dataset3658_release1_LPDMFLEXPARTAC14.ames
# HALO-DB_dataset3659_release1_LPDMFLEXPARTAC15.ames
# HALO-DB_dataset3661_release1_LPDMFLEXPARTAC16.ames
# HALO-DB_dataset3662_release1_LPDMFLEXPARTAC17.ames
# HALO-DB_dataset3663_release1_LPDMFLEXPARTAC18.ames
# HALO-DB_dataset3664_release1_LPDMFLEXPARTAC19.ames
# HALO-DB_dataset3665_release1_LPDMFLEXPARTAC20.ames
# HALO-DB_dataset3666_release1_LPDMFLEXPARTAC21.ames
# HALO-DB_dataset3667_release1_LPDMFLEXPARTAC22.ames
#
# 0  files with header error:
#
# 23  files with incomplete data rows:
# HALO-DB_dataset3019_release1_AC09_2014_09_11_CAS_V1.ames
# HALO-DB_dataset3020_release1_AC10_2014_09_12_CAS_V1.ames
# HALO-DB_dataset3021_release1_AC11_2014_09_16_CAS_V1.ames
# HALO-DB_dataset3022_release1_AC12_2014_09_18_CAS_V1.ames
# HALO-DB_dataset3023_release1_AC13_2014_09_19_CAS_V1.ames
# HALO-DB_dataset3024_release1_AC14_2014_09_21_CAS_V1.ames
# HALO-DB_dataset3025_release1_AC15_2014_09_23_CAS_V1.ames
# HALO-DB_dataset3026_release1_AC16_2014_09_25_CAS_V1.ames
# HALO-DB_dataset3027_release1_AC17_2014_09_27_CAS_V1.ames
# HALO-DB_dataset3029_release1_AC18_2014_09_28_CAS_V1.ames
# HALO-DB_dataset3030_release1_AC19_2014_09_30_CAS_V1.ames
# HALO-DB_dataset3031_release1_AC20_2014_10_01_CAS_V1.ames
# HALO-DB_dataset3032_release1_AC21_2014_10_03_CAS_V1.ames
# HALO-DB_dataset3033_release1_AC22_2014_10_04_CAS_V1.ames
# HALO-DB_dataset3421_release2_ACRIDICON_AC06_SID3_SD.ames
# HALO-DB_dataset3915_release1_Hotwire_AC10__12_09_2014_ACRIDICON.ames
# HALO-DB_dataset3916_release1_Hotwire_AC11__16_09_2014_ACRIDICON.ames
# HALO-DB_dataset3917_release1_CAS_DPOL_AC12__18_09_2014_ACRIDICON.ames
# HALO-DB_dataset3922_release1_Hotwire_AC17__27_09_2014_ACRIDICON.ames
# HALO-DB_dataset3923_release1_Hotwire_AC18__28_09_2014_ACRIDICON.ames
# HALO-DB_dataset3924_release1_Hotwire_AC19__30_09_2014_ACRIDICON.ames
# HALO-DB_dataset3925_release1_Hotwire_AC20__01_10_2014_ACRIDICON.ames
# HALO-DB_dataset3927_release1_Hotwire_AC22__04_10_2014_ACRIDICON.ames
#
# 1  files with unknown error:
# HALO-DB_dataset3016_release3_CToFAMS_AC10_HASI_20140912.ames

# %%
# MORE NOTES

# dataset 3421: corrected n_vars to 18

# dataset 3915: lines 6012-6016 missing LWC; I changed to error flag value

# dataset 3916: lines 13966-13983 missing LWC; I changed to error flag value

# dataset 3917: missing a column

# dataset 3922: lines [13690, 13693, 13694, 13782, 13784, 13788, 13789, 13790, 
# 13791, 13792, 13793, 13794, 18929, 18930, 18931, 18932, 18934, 18935, 19527, 
# 19528, 19529, 19531, 19532, 19533, 19535, 19536, 19537] + 1 missing LWC; I changed to error flag value

# dataset 3923: lines [3644, 3645, 3646, 3647, 3741, 3742, 3743, 3744, 3745, 
# 3746, 3747, 3772, 3773, 3826, 3827, 3828, 3829, 3830, 3831, 3832, 3833, 3938, 
# 3939, 3940, 3941, 3942, 3943, 3944, 4887, 4888, 4889, 4890, 4891, 7262, 7263, 
# 7264, 7265] + 1 missing LWC; I changed to error flag value

# dataset 3924: lines [5152, 12132, 12133, 12134, 12135, 13244, 13245, 13246, 
# 13247, 13248, 13249, 13452, 13453, 13454, 13455, 13456, 13457, 13458] + 1 
# missing LWC; I changed to error flag value

# dataset 3925: lines [21269, 21277, 21355, 21471, 21505, 21588, 21701, 21776, 
# 21777, 21778, 21779, 21780, 21781, 21782, 21783, 21784, 21785, 21786, 21787, 
# 21788, 21789, 21790, 21791, 21792, 21793, 21794, 21795, 21796, 21797, 21798, 
# 21800, 21801, 21802, 21803, 21804, 21805, 21806, 21807, 21808, 21809, 21810, 
# 21811, 21812, 21813, 21814, 21815, 21816, 21817, 21818, 21819, 21820, 21821, 
# 21822, 21823, 21824, 21825, 21826, 21827, 21828, 21829, 21830, 21831, 21832, 
# 21833, 21834, 21835, 21836, 21837, 21838, 21880, 21881, 21882, 21962, 21963, 
# 21972, 21973, 21974, 21975, 21984, 21985, 21986, 21987, 21988, 22033, 22034, 
# 22090, 22095, 22114, 22115, 22116, 22117, 22118, 22119, 22120, 22121, 22122, 
# 22123, 22124, 22125, 22126, 22232, 22234, 22253, 22257, 22258, 22260, 22424, 
# 23217, 23237, 23238, 23240, 23241, 23242, 23244, 23245, 23247, 23253, 23256, 
# 23260, 23261, 23275, 23276, 23278, 23279, 23512, 23513, 23515, 23516, 23520, 
# 23521, 23522, 23523, 23524, 23525, 23526, 23528, 23530, 23531, 23532, 23533, 
# 23534, 23535, 23536, 23537, 23539, 23540, 23541, 23544, 23546, 23547, 23548, 
# 23551, 23560, 24258, 24259, 24260, 24264] + 1 missing LWC; I changed to error flag value

# dataset 3927: lines [21853, 21854, 21855, 21856, 21857, 21858, 21859, 21860, 
# 21861, 21862, 21863, 21864, 21865, 21866, 21867, 21868, 21869, 21870, 21871, 
# 21872, 21873, 21874, 21875, 21876, 21877, 21878, 21879, 21880, 21881, 21882, 
# 21883, 21884, 21885, 21886, 21887, 21888, 21889, 21890, 21891, 21892, 21893, 
# 21894, 21895, 21896, 21897, 21898, 21899, 21900, 21901, 21902, 21903, 21904, 
# 21905, 21906, 21907, 21908, 21909, 21910, 21911, 21912, 21913, 21914, 21915, 
# 21916, 21917, 21918, 21919, 21920, 21921, 21922, 21923, 21924, 21925, 21926, 
# 21927, 21928, 21929, 21930, 21931, 21932, 21933, 21934, 21935, 21936] missing LWC; I changed to error flag value

# datasets labeled 'image_analysis' were excluded for third run

# datasets 3649-6367 (non-1001 type) were excluded for third run

# %%
# automated correction of incomplete rows, following second run (other ones I did manually but these were too long)
# 'COPY' files subsequently replaced original files (manually).
filenames = ['HALO-DB_dataset3925_release1_Hotwire_AC20__01_10_2014_ACRIDICON.ames', 
             'HALO-DB_dataset3927_release1_Hotwire_AC22__04_10_2014_ACRIDICON.ames']
new_filenames = ['HALO-DB_dataset3925_release1_Hotwire_AC20__01_10_2014_ACRIDICON_COPY.ames', 
             'HALO-DB_dataset3927_release1_Hotwire_AC22__04_10_2014_ACRIDICON_COPY.ames']
inds = [21, 22]

for i, filename in enumerate(filenames):
    f = open(filename, "r")
    lines = f.readlines()
    f.close()
    
    new_f = open(new_filenames[i], "w")
    new_lines = [0 for i in range(len(lines))]
    
    err_line_inds = []
    for tup in incomplete_error[inds[i]]['error_data']:
        err_line_inds.append(tup[1])
    
    for j, line in enumerate(lines):
        if j in err_line_inds:
            split_line = line.split()
            new_lines[j] = split_line[0] + ' ' + '-9999.0000' + ' ' + split_line[1] + '\n'
        else:
            new_lines[j] = line
    
    new_f.writelines(new_lines)
    new_f.close()

# %%
# THIRD RUN #

print(len(all_good), ' files processed with no error.')
print()
print(len(ames_error), ' files not in ames 1001-type format:')
for thing in ames_error:
    print(thing['filename'])
print()    
print(len(header_error), ' files with header error:')
for thing in header_error:
    print(thing['filename'])
print()    
print(len(incomplete_error), ' files with incomplete data rows:')
for thing in incomplete_error:
    print(thing['filename'])
print()
print(len(other_error), ' files with unknown error:')
for thing in other_error:
    print(thing['filename'])
# Out:
# 360  files processed with no error.
#
# 0  files not in ames 1001-type format:
#
# 0  files with header error:
#
# 15  files with incomplete data rows:
# HALO-DB_dataset3019_release1_AC09_2014_09_11_CAS_V1.ames
# HALO-DB_dataset3020_release1_AC10_2014_09_12_CAS_V1.ames
# HALO-DB_dataset3021_release1_AC11_2014_09_16_CAS_V1.ames
# HALO-DB_dataset3022_release1_AC12_2014_09_18_CAS_V1.ames
# HALO-DB_dataset3023_release1_AC13_2014_09_19_CAS_V1.ames
# HALO-DB_dataset3024_release1_AC14_2014_09_21_CAS_V1.ames
# HALO-DB_dataset3025_release1_AC15_2014_09_23_CAS_V1.ames
# HALO-DB_dataset3026_release1_AC16_2014_09_25_CAS_V1.ames
# HALO-DB_dataset3027_release1_AC17_2014_09_27_CAS_V1.ames
# HALO-DB_dataset3029_release1_AC18_2014_09_28_CAS_V1.ames
# HALO-DB_dataset3030_release1_AC19_2014_09_30_CAS_V1.ames
# HALO-DB_dataset3031_release1_AC20_2014_10_01_CAS_V1.ames
# HALO-DB_dataset3032_release1_AC21_2014_10_03_CAS_V1.ames
# HALO-DB_dataset3033_release1_AC22_2014_10_04_CAS_V1.ames
# HALO-DB_dataset3917_release1_CAS_DPOL_AC12__18_09_2014_ACRIDICON.ames
#
# 0  files with unknown error:

# %%
# store all_good variable; call %store -r to reopen in future sessions
# %store all_good
# Out:
# Stored 'all_good' (list)

# %%
# Convert to csv files
import csv

for i, file in enumerate(all_good):
    new_filename = file['filename'][0:len(file['filename'])-5]+'.csv'
    new_data = []
    new_data.append(file['infile_date'])
    new_data.append(file['var_names'])
    new_data.append(file['err_vals'])
    for thing in file['data']:
        new_data.append(thing)
    with open(new_filename, 'w', newline='') as writeFile:
        writer = csv.writer(writeFile)
        writer.writerows(new_data)
    writeFile.close()

# %%
# %store -r

# %%
with open('good_ames_files.txt', 'w') as writeFile:
        for file in all_good:
            writeFile.write(file['filename']+'\n')
writeFile.close()
